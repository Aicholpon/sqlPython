# %%
import pymysql
import pandas as pd
from collections import Counter
conn = pymysql.connect(
host='198.199.81.151',
port=3306,
user='aicholpon', 
passwd='qwerty',
db='test',
charset='utf8mb4')
print("connection successful!"
)
# Out:
# connection successful!

# %%
df = pd.read_sql_query(
    "SELECT FullNameRu, Founders FROM Minjust2018 LIMIT 0, 50",
    conn)
df.tail(50)
# Out:
#                                            FullNameRu  \
# 0   Жалал-Абадский филиал открытого акционерного о...
# 1   У-е " Центр спортивной медицины и реаблитации ...
# 2   Жалал-Абадский филиал открытого акционерного о...
# 3         Крестиьянское хозяйство "Алтынбек-Эркинбек"
# 4                                     ООО "Турандот"
# 5                  Общественный фонд "Кызылтоо-Озгон"
# 6                     ОФ "TOEFL CENTER" (Тоэфл центр)
# 7   Сельскохозяйственный кооператив "Кубанычбек Ат...
# 8         Товарищество собственников жилья "Вербена"
# 9                    Обшественный фонд  "Лайф Плюс"
# 10                       Общественный фонд "Жоро-Ата"
# 11  Учреждение "Араванская и Карасуйская межрайонн...
# 12                                     "Абант Сервис"
# 13  Общество с ограниченной ответственностью ""АЗИ...
# 14                           "Кыргызстан айыл окмоту"
# 15  Общество с ограниченной ответственностью"Айбат...
# ...

# %%
def find_founders_related_to_founders_via_companies(founders, db_connection=conn):
    frames = [] 
    for founder in founders:
        frames.append(find_founders_by_name(founder, db_connection))
    df = pd.concat(frames) # TODO remove duplicates
    return find_related_founders_by_companies(df, db_connection)
    
    
def find_related_founders_by_companies(founders_dataframe, db_connection=conn):
    founders_array = founders_dataframe.values
    founders_list = list(map(find_founders_by_companies_string, founders_array))
    data = {}
    for i, founders in enumerate(founders_array):
        data[founders[0]] = founders_list[i]
    return data

def find_founders_by_companies_string(founder_with_companies, db_connection=conn):
    companies_list = founder_with_companies[1].split(',')
    #companies_list = list(map(find_companies_by_founder, founders_list))
    data = {}
    for i, company in enumerate(companies_list):
        data[company] = find_companies_by_founder(company, founder_with_companies[0], db_connection)
    return data

def find_founders_by_company(company, nosearch, db_connection=conn):
    df = pd.read_sql_query(
    "SELECT FullNameRu FROM Minjust2018 WHERE Founders LIKE '%"+ founder +"%' AND FullNameRu <> '"+nosearch+"' LIMIT 0, 10",
    db_connection)
    return df.values.tolist()

def find_founders_by_name(name, db_connection=conn):
    df = pd.read_sql_query(
    "SELECT FullNameRu, Founders FROM Minjust2018 WHERE Founders LIKE '%"+name+"%' LIMIT 0, 20",
    db_connection)
    return df

# %%
df = find_founders_by_name ("абант сервис")
print (df)
print (df.values)
# Out:
# Empty DataFrame
# Columns: [FullNameRu, Founders]
# Index: []
# []

# %%
founders = find_founders_related_to_founders_via_companies ([""])
print (json.dumps(founders, indent=2, ensure_ascii=False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3145f0290a93> in <module>()
# ----> 1 founders = find_founders_related_to_founders_via_companies ([""])
#       2 print (json.dumps(founders, indent=2, ensure_ascii=False))
#
# <ipython-input-2-8528819090e5> in find_founders_related_to_founders_via_companies(founders, db_connection)
#       4         frames.append(find_founders_by_name(founder, db_connection))
#       5     df = pd.concat(frames) # TODO remove duplicates
# ----> 6     return find_related_founders_by_companies(df, db_connection)
#       7
#       8
#
# <ipython-input-2-8528819090e5> in find_related_founders_by_companies(founders_dataframe, db_connection)
#       9 def find_related_founders_by_companies(founders_dataframe, db_connection=conn):
#      10     founders_array = founders_dataframe.values
# ...
